# %% [markdown]
# # Explore Various Retrieval Strategies with Retrievers in LangChain

# %% [markdown]
# ## Install OpenAI, and LangChain dependencies

# %%
# !pip install langchain==0.3.11
# !pip install langchain-openai==0.2.12
# !pip install langchain-community==0.3.11
# Out:
# Requirement already satisfied: langchain==0.3.11 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (0.3.11)
# Requirement already satisfied: PyYAML>=5.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (3.11.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (0.3.2)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain==0.3.11) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.11) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.11) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (4.7.0)
# Requirement already satisfied: httpcore==1.* in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.3.1)
# Requirement already satisfied: langchain-openai==0.2.12 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (0.2.12)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-openai==0.2.12) (0.3.28)
# Requirement already satisfied: openai<2.0.0,>=1.55.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-openai==0.2.12) (1.58.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-openai==0.2.12) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.8.2)
# Requirement already satisfied: sniffio in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.12) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.12) (2.32.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.2.2)
# Requirement already satisfied: idna>=2.8 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (3.10)
# Requirement already satisfied: certifi in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai==0.2.12) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.12) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.12) (2.3.0)
# Requirement already satisfied: colorama in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.55.3->langchain-openai==0.2.12) (0.4.6)
# Requirement already satisfied: langchain-community==0.3.11 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (0.3.11)
# Requirement already satisfied: PyYAML>=5.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.11 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (0.3.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (0.3.28)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (2.7.0)
# Requirement already satisfied: requests<3,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-community==0.3.11) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.11) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.3.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.3.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.3.11) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.3.11) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (4.7.0)
# Requirement already satisfied: httpcore==1.* in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.3.1)

# %% [markdown]
# ## Install Chroma Vector DB and LangChain wrapper

# %%
# !pip install langchain-chroma
# Out:
# Requirement already satisfied: langchain-chroma in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (0.2.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-chroma) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-chroma) (0.115.6)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-chroma) (0.3.28)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.10.13)
# Requirement already satisfied: httpx>=0.27.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.41.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (24.2)
# Requirement already satisfied: pyproject_hooks in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (8.5.0)
# Requirement already satisfied: tomli>=1.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: anyio in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.7.0)
# Requirement already satisfied: certifi in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: idna in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.32.3)
# Requirement already satisfied: requests-oauthlib in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.0.0)
# Requirement already satisfied: coloredlogs in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (24.12.23)
# Requirement already satisfied: protobuf in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (5.29.2)
# Requirement already satisfied: sympy in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.26.5)
# Requirement already satisfied: click>=8.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (14.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from importlib-resources->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.21.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: filelock in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2024.12.0)
# Requirement already satisfied: mdurl~=0.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.4.1)
# Requirement already satisfied: humanfriendly>=9.1 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\2. my workspace and notes\1. demystify folders\generativeai-demystified\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)

# %% [markdown]
# ## Enter Open AI API Key

# %%
from getpass import getpass

OPENAI_KEY = getpass('Enter Open AI API Key: ')

# %% [markdown]
# ## Setup Environment Variables

# %%
import os

os.environ['OPENAI_API_KEY'] = OPENAI_KEY

# %% [markdown]
# ### Open AI Embedding Models
#
# LangChain enables us to access Open AI embedding models which include the newest models: a smaller and highly efficient `text-embedding-3-small` model, and a larger and more powerful `text-embedding-3-large` model.

# %%
from langchain_openai import OpenAIEmbeddings

# details here: https://openai.com/blog/new-embedding-models-and-api-updates
openai_embed_model = OpenAIEmbeddings(model='text-embedding-3-small')

# %% [markdown]
# ## Vector Databases
#
# One of the most common ways to store and search over unstructured data is to embed it and store the resulting embedding vectors, and then at query time to embed the unstructured query and retrieve the embedding vectors that are 'most similar' to the embedded query. A vector database takes care of storing embedded data and performing vector search for you.
#
# ### Chroma Vector DB
#
# [Chroma](https://docs.trychroma.com/getting-started) is a AI-native open-source vector database focused on developer productivity and happiness. Chroma is licensed under Apache 2.0.

# %% [markdown]
# ### Create a Vector DB and persist on disk
#
# Here we initialize a connection to a Chroma vector DB client, and also we want to save to disk, so we simply initialize the Chroma client and pass the directory where we want the data to be saved to.

# %%
docs = [
 'Quantum mechanics describes the behavior of very small particles.',
 'Photosynthesis is the process by which green plants make food using sunlight.',
 'Artificial Intelligence aims to create machines that can think and learn.',
 'The pyramids of Egypt are historical monuments that have stood for thousands of years.',
 'New Delhi is the capital of India and the seat of all three branches of the Government of India.',
 'Biology is the study of living organisms and their interactions with the environment.',
 'Music therapy can aid in the mental well-being of individuals.',
 'Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.',
 'The Milky Way is just one of billions of galaxies in the universe.',
 'Economic theories help understand the distribution of resources in society.',
 'Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.',
 'Yoga is an ancient practice that involves physical postures and meditation.'
]

# %%
from langchain_chroma import Chroma

# create vector DB of docs and embeddings - takes 1 min on Colab
chroma_db = Chroma.from_texts(texts=docs, collection_name='db_docs',
                              # need to set the distance function to cosine else it uses euclidean by default
                              # check https://docs.trychroma.com/guides#changing-the-distance-function
                              collection_metadata={"hnsw:space": "cosine"},
                              embedding=openai_embed_model)

# %% [markdown]
# ## Vector Database Retrievers
#
# Here we will explore the following retrieval strategies on our Vector Database:
#
# - Similarity or Ranking based Retrieval
# - Similarity with Threshold Retrieval
# - Custom Retriever with Similarity Scores + Thresholding
# - Multi Query Retrieval
# - Contextual Compression Retrieval
# - Ensemble Retrieval

# %% [markdown]
# ### Similarity or Ranking based Retrieval
#
# We use cosine similarity here and retrieve the top 3 similar documents based on the user input query

# %%
similarity_retriever = chroma_db.as_retriever(search_type="similarity",
                                              search_kwargs={"k": 3})

# %%
query = "what is the capital of India?"
top3_docs = similarity_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "what is the old capital of India?"
top3_docs = similarity_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.')]

# %%
query = "how do plants make food?"
top3_docs = similarity_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.'),
#  Document(id='e736cbba-9d8e-48ef-b91a-5271dca5ede5', metadata={}, page_content='Biology is the study of living organisms and their interactions with the environment.'),
#  Document(id='d317075b-18e1-41c9-b9f2-e02a4f4e03f3', metadata={}, page_content='Artificial Intelligence aims to create machines that can think and learn.')]

# %% [markdown]
# We use maximum marginal relevance ranking here and retrieve the top 3 similar documents based on the user input query

# %%
mmr_retriever = chroma_db.as_retriever(search_type="mmr",
                                       search_kwargs={"k": 3,
                                                      'fetch_k': 10})

# %%
query = "what is the capital of India?"
top3_docs = mmr_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "what is the old capital of India?"
top3_docs = mmr_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='16b07d32-3722-48ac-be73-2184c38b3623', metadata={}, page_content='Yoga is an ancient practice that involves physical postures and meditation.')]

# %%
query = "how do plants make food?"
top3_docs = mmr_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.'),
#  Document(id='d317075b-18e1-41c9-b9f2-e02a4f4e03f3', metadata={}, page_content='Artificial Intelligence aims to create machines that can think and learn.'),
#  Document(id='412a8cbe-d99f-4ad5-88c6-943781e47c71', metadata={}, page_content='Economic theories help understand the distribution of resources in society.')]

# %% [markdown]
# ### Similarity with Threshold Retrieval
#
# We use cosine similarity here and retrieve the top 3 similar documents based on the user input query and also introduce a cutoff to not return any documents which are below a certain similarity threshold

# %%
similarity_threshold_retriever = chroma_db.as_retriever(search_type="similarity_score_threshold",
                                                        search_kwargs={"k": 3,
                                                                       "score_threshold": 0.3})

# %%
query = "what is the capital of India?"
top3_docs = similarity_threshold_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "what is the old capital of India?"
top3_docs = similarity_threshold_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.')]

# %%
query = "how do plants make food?"
top3_docs = similarity_threshold_retriever.invoke(query)
top3_docs
# Out:
# [Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.')]

# %% [markdown]
# ### Custom Retriever with Similarity Scores + Thresholding
#
# Here we will create a custom retriever which will:
#
# - Retrieve documents with cosine distance
# - Convert to similarity score and apply thresholding
# - Return topk documents above a similarity threshold

# %%
query = 'how do plants make food?'
chroma_db.similarity_search_with_score(query, k=3)
# Out:
# [(Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.'),
#   0.35381996631622314),
#  (Document(id='e736cbba-9d8e-48ef-b91a-5271dca5ede5', metadata={}, page_content='Biology is the study of living organisms and their interactions with the environment.'),
#   0.8317285776138306),
#  (Document(id='d317075b-18e1-41c9-b9f2-e02a4f4e03f3', metadata={}, page_content='Artificial Intelligence aims to create machines that can think and learn.'),
#   0.8765017986297607)]

# %%
chroma_db._select_relevance_score_fn()
# Out:
# <function langchain_core.vectorstores.base.VectorStore._cosine_relevance_score_fn(distance: 'float') -> 'float'>

# %%
# converts cosine distance to similarity; cosine_similarity = 1 - cosine_distance
cosine_sim = chroma_db._select_relevance_score_fn()
cosine_sim(0.35375)
# Out:
# 0.64625

# %%
from typing import List
from langchain_core.documents import Document
from langchain_core.runnables import chain

@chain
def custom_retriever(query: str, topk=3, threshold_score=0.3) -> List[Document]:
    # get similarity conversion function (converts cosine distance to similarity)
    cosine_sim = chroma_db._select_relevance_score_fn()
    # get topk documents with lowest cosine distance
    docs, scores = zip(*chroma_db.similarity_search_with_score(query, k=topk))
    final_docs = []
    for doc, score in zip(docs, scores):
        # convert cosine distance to similarity
        score = cosine_sim(score)
        doc.metadata["score"] = round(score, 3)
        # check if score is above threshold
        if score > threshold_score:
            final_docs.append(doc)

    return final_docs

# %%
query = "what is the financial capital of India?"
top3_docs = custom_retriever.invoke(query, topk=3, threshold_score=0.51)
top3_docs
# Out:
# [Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={'score': 0.69}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={'score': 0.54}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.')]

# %%
query = 'how do plants make food?'
top3_docs = custom_retriever.invoke(query, topk=3, threshold_score=0.5)
top3_docs
# Out:
# [Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={'score': 0.646}, page_content='Photosynthesis is the process by which green plants make food using sunlight.')]

# %% [markdown]
# ### Multi Query Retrieval
#
# Retrieval may produce different results with subtle changes in query wording, or if the embeddings do not capture the semantics of the data well. Prompt engineering / tuning is sometimes done to manually address these problems, but can be tedious.
#
# The [`MultiQueryRetriever`](https://api.python.langchain.com/en/latest/retrievers/langchain.retrievers.multi_query.MultiQueryRetriever.html) automates the process of prompt tuning by using an LLM to generate multiple queries from different perspectives for a given user input query. For each query, it retrieves a set of relevant documents and takes the unique union across all queries to get a larger set of potentially relevant documents.

# %%
from langchain_openai import ChatOpenAI

chatgpt = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever
# Set logging for the queries
import logging

similarity_retriever = chroma_db.as_retriever(search_type="similarity",
                                              search_kwargs={"k": 3})

mq_retriever = MultiQueryRetriever.from_llm(
    retriever=similarity_retriever, llm=chatgpt
)

logging.basicConfig()
# so we can see what queries are generated by the LLM
logging.getLogger("langchain.retrievers.multi_query").setLevel(logging.INFO)

# %%
query = "financial capital of India?"
docs = mq_retriever.invoke(query)
docs
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['What is the capital city of India in terms of its financial significance?  ', 'Which city in India serves as the financial hub of the country?  ', 'Can you tell me about the financial capital of India?']
# [Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "old capital of India?"
docs = mq_retriever.invoke(query)
docs
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['What was the former capital of India?  ', "Which city served as India's capital before the current one?  ", 'Can you tell me the historical capital of India?']
# [Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.'),
#  Document(id='d1319620-c5c8-4c67-aa4f-1ac6a558c0f5', metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.')]

# %% [markdown]
# ### Contextual Compression Retrieval
#
# The information most relevant to a query may be buried in a document with a lot of irrelevant text. Passing that full document through your application can lead to more expensive LLM calls and poorer responses.
#
# Contextual compression is meant to fix this. The idea is simple: instead of immediately returning retrieved documents as-is, you can compress them using the context of the given query, so that only the relevant information is returned.
#
# This compression can happen in the form of:
#
# - Remove parts of the content of retrieved documents which are not relevant to the query. This is done by extracting only relevant parts of the document to the given query
#
# - Filter out documents which are not relevant to the given query but do not remove content from the document

# %% [markdown]
# Here we wrap our base cosine distance retriever with a `ContextualCompressionRetriever`. Then we'll add an `LLMChainExtractor`, which will iterate over the initially returned documents and extract from each only the content that is relevant to the query.

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# simple cosine distance based retriever
similarity_retriever = chroma_db.as_retriever(search_type="similarity",
                                              search_kwargs={"k": 3})

# extracts from each document only the content that is relevant to the query
compressor = LLMChainExtractor.from_llm(llm=chatgpt)

# retrieves the documents similar to query and then applies the compressor
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=similarity_retriever
)

# %%
query = "what is the financial capital of India?"
docs = compression_retriever.invoke(query)
docs
# Out:
# [Document(metadata={}, page_content='Mumbai is the financial capital and the most populous city of India.')]

# %%
query = "what is the old capital of India?"
docs = compression_retriever.invoke(query)
docs
# Out:
# [Document(metadata={}, page_content='Calcutta served as the de facto capital of India until 1911.')]

# %% [markdown]
# The `LLMChainFilter` is slightly simpler but more robust compressor that uses an LLM chain to decide which of the initially retrieved documents to filter out and which ones to return, without manipulating the document contents.

# %%
from langchain.retrievers.document_compressors import LLMChainFilter

#  decides which of the initially retrieved documents to filter out and which ones to return
_filter = LLMChainFilter.from_llm(llm=chatgpt)

# retrieves the documents similar to query and then applies the filter
compression_retriever = ContextualCompressionRetriever(
    base_compressor=_filter, base_retriever=similarity_retriever
)

# %%
query = "what is the financial capital of India?"
docs = compression_retriever.invoke(query)
docs
# Out:
# [Document(id='3695ad82-a317-4d7f-997c-5c97c98ba3aa', metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.')]

# %%
query = "what is the old capital of India?"
docs = compression_retriever.invoke(query)
docs
# Out:
# [Document(id='ffcd2220-f967-4903-95c0-be39cc1de7f0', metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "how do plants live?"
docs = compression_retriever.invoke(query)
docs
# Out:
# [Document(id='13a1621d-890e-4d02-920e-f21dc578c50e', metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.')]

# %% [markdown]
# ### Ensemble Retrieval
#
# The `EnsembleRetriever` takes a list of retrievers as input and ensemble the results of each of their retrievals and rerank the results based on the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm.

# %%
from langchain.retrievers import EnsembleRetriever

# simple cosine distance based retriever
similarity_retriever = chroma_db.as_retriever(search_type="similarity",
                                              search_kwargs={"k": 3})

# retrieves the documents similar to query and then applies the filter
compression_retriever = ContextualCompressionRetriever(
    base_compressor=_filter, base_retriever=similarity_retriever
)


ensemble_retriever = EnsembleRetriever(
    retrievers=[compression_retriever, similarity_retriever],
    weights=[0.7, 0.3]
)

# %%
query = "what is the financial capital of India?"
docs = ensemble_retriever.invoke(query)
docs
# Out:
# [Document(metadata={}, page_content='Mumbai is the financial capital and the most populous city of India. It is the financial, commercial, and entertainment capital of South Asia.'),
#  Document(metadata={}, page_content='New Delhi is the capital of India and the seat of all three branches of the Government of India.'),
#  Document(metadata={}, page_content='Kolkata is the de facto cultural capital of India and a historically and culturally significant city. Calcutta served as the de facto capital of India until 1911.')]

# %%
query = "how do plants live?"
docs = ensemble_retriever.invoke(query)
docs
# Out:
# [Document(metadata={}, page_content='Photosynthesis is the process by which green plants make food using sunlight.'),
#  Document(metadata={}, page_content='Biology is the study of living organisms and their interactions with the environment.'),
#  Document(metadata={}, page_content='Music therapy can aid in the mental well-being of individuals.')]

# %% [markdown]
# We will cover more retrieval strategies in the Advanced Course on RAG and LangChain in the future including:
#
# - Self Query Retrieval
# - Hybrid Search Retrieval
# - Parent Document Retrieval
# - Reranker Retrieval
#
# and more...
