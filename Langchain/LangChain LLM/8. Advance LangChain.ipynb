# %%
from getpass import getpass

OPENAI_KEY = getpass('Enter Open AI API Key: ')

# %%
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
