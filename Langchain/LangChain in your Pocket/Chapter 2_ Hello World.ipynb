# %%
import os
from dotenv import load_dotenv
import os
# os.environ["OPENAI_API_KEY"] = apikey # set the API key

# %%
# Load the .env file
load_dotenv()
# Out:
# True

# %%
print(os.environ)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\Sourav Banerjee\\AppData\\Roaming', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_53756_UUCSMESSDWEJAZRA', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'LAPTOP-FJ9434OT', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': 'C:\\Users\\Sourav Banerjee\\anaconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\Sourav Banerjee\\anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\Sourav Banerjee\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\Sourav Banerjee\\anaconda3', 'CONDA_SHLVL': '1', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_13352': '1', 'ELECTRON_RUN_AS_NODE': '1', 'HADOOP_HOME': 'C:\\hadoop27', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\Sourav Banerjee', 'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2021.3.3\\bin;', 'JAVA_HOME': 'C:\\Program Files\\Java\\jdk1.8.0_311', 'JPY_INTERRUPT_EVENT': '1480', 'KAFKA_HOME': 'D:\\kafka28', 'LOCALAPPDATA': 'C:\\Users\\Sourav Banerjee\\AppData\\Local', 'LOGONSERVER': '\\\\LAPTOP-FJ9434OT', 'MAVEN_HOME': 'C:\\apache-maven-3.9.3', 'NUMBER_OF_PROCESSORS': '16', 'ONEDRIVE': 'C:\\Users\\Sourav Banerjee\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\Sourav Banerjee\\anaconda3;C:\\Users\\Sourav Banerjee\\anaconda3;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\usr\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Scripts;C:\\Users\\Sourav Banerjee\\anaconda3\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\condabin;C:\\Program Files (x86)\\Microsoft SDKs\\Azure\\CLI2\\wbin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files (x86)\\Microsoft SQL Server\\150\\DTS\\Binn;C:\\Program Files\\Git\\cmd;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\dotnet;C:\\Program Files\\Microsoft SQL Server\\130\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn;C:\\Program Files (x86)\\sbt\\bin;C:\\apache-maven-3.9.3\\bin;C:\\terraform;C:\\Users\\Sourav Banerjee\\anaconda3;C:\\Users\\Sourav Banerjee\\anaconda3\\Scripts;.;C:\\Program Files\\NVIDIA Corporation\\NVIDIA app\\NvDLISR;C:\\Binaries;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\usr\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Library\\bin;C:\\Users\\Sourav Banerjee\\anaconda3\\Scripts;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin;C:\\Users\\Sourav Banerjee\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Program Files\\Azure Data Studio\\bin;C:\\Program Files\\JetBrains\\PyCharm Community Edition 2021.2.2\\bin;C:\\Program Files\\Java\\jdk1.8.0_311\\bin;C:\\Spark\\spark3\\bin;C:\\hadoop27\\bin;C:\\Spark\\spark3\\python\\lib\\py4j-0.10.9-src.zip;C:\\mongosh;C:\\Users\\Sourav Banerjee\\.dotnet\\tools;D:\\kafka28\\bin\\windows;C:\\Program Files\\MongoDB\\Server\\5.0\\bin;D:\\1. Study Materials\\8. NOSQL DATABASE\\MONGODB\\mongodb-database-tools-windows-x86_64-100.5.1\\bin;C:\\Users\\Sourav Banerjee\\AppData\\Local\\Coursier\\data\\bi;C:\\Users\\Sourav Banerjee\\AppData\\Local\\GitHubD;C:\\Hugo\\bin;C:\\P;C:\\Users\\Sourav Banerjee\\AppData\\Local\\Microsoft\\WinGet\\Packages\\Databricks.DatabricksCLI_Microsoft.Winget.Source_8wekyb3d8bbwe;C:\\Users\\Sourav Banerjee\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\Sou ...

# %%
from langchain_openai.llms import OpenAI
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import PromptTemplate

llm = OpenAI() # Create a new instance of the OpenAI class.
chat_llm = ChatOpenAI()

# %%
#2.2 Name Generator
from langchain.chains import LLMChain
from langchain.schema.runnable import RunnableSequence

prompt = PromptTemplate.from_template(" Suggest {number} names for a {domain} startup?") # Create a new instance of the PromptTemplate class.

chain = LLMChain(llm=llm, prompt=prompt) # Create a new instance of the LLMChain class.
chain1 = prompt | llm # Create a new instance of the LLMChain class.
chain2 = RunnableSequence(prompt, llm) # Create a new instance of the RunnableSequence class.
 
print(chain.run({'number':'5','domain':'cooking'})) # Run the chain with the input dictionary.
print(chain1.invoke({'number':'2','domain':'AI'}))  # Run the chain with the input dictionary.
print(chain2.invoke({'number':'3','domain':'EdTech'}))  # Run the chain with the input dictionary.
# Out:
# 1. "Sizzle & Spice"
# 2. "Gourmet Kitchen Co."
# 3. "Flavors & Feasts"
# 4. "The Culinary Collective"
# 5. "Kitchen Creations Co."
#
#
# 1. MindLogic
# 2. NeuralGenius
#
#
# 1. "LearnGenius"
# 2. "EduHive"
# 3. "KnowledgeLink"

# %%
from langchain_openai.chat_models import ChatOpenAI

# the building blocks
template = ChatPromptTemplate.from_messages([
    ('system', 'You are a helpful assistant.'),
    ('human', '{question}'),
])

# Initialize the ChatOpenAI model with the API key



# Example usage of the model
response = chat_llm.invoke(template.format(question="What is the capital of France?"))
print(response.content)

print("--------------------")
chain = template | chat_llm
# use it
result = chain.invoke({
    "question": "Which model providers offer LLMs? Provide the output in Json Format with keys as Name, Description, and URL."
})
print(result.content)
# Out:
# Assistant: The capital of France is Paris.
# --------------------
# ```json
# [
#     {
#         "Name": "Tulane University Law School",
#         "Description": "Tulane offers an LLM program in U.S. Law and other specialized areas of law.",
#         "URL": "https://law.tulane.edu/academics/llm-program"
#     },
#     {
#         "Name": "Harvard Law School",
#         "Description": "Harvard Law School offers an LLM program for international students and legal professionals.",
#         "URL": "https://hls.harvard.edu/academics/graduate-programs/llm-program/"
#     },
#     {
#         "Name": "New York University School of Law",
#         "Description": "NYU School of Law offers various LLM programs in different legal fields.",
#         "URL": "https://www.law.nyu.edu/llmjsd"
#     }
# ]
# ```

# %%
#2.3 Text Pre-processing

prompt = PromptTemplate.from_template("Preprocess the given text by following the given steps in sequence. Follow only those steps which have a yes. Remove Number:{number},Remove punctuations:{punc}, Word stemming :{stem}. Output just the preprocessed text. Text:{text}")


chain = prompt | llm # Create a new instance of the LLMChain class.

print(chain.invoke({'text':'Hey !! I got 12 out of 20 in Swimming','number':'yes','punc':'yes','stem':'no'}))
print(chain.invoke({'text':'22 13B is my flat no. Rohit will be joining us for the party','number':'yes','punc':'no','stem':'yes'}))
# Out:
# Hey !! I got out of in Swimming
#
#
#  flat rohit join us party
#
#
# flat rohit join us party

# %%
#2.4 Storyteller


prompt = PromptTemplate.from_template(" Complete a {length} story in using the given beginning. The genre should be {genre} and the story should have an apt ending. Beginning: {text}")

chain = LLMChain(llm=llm, prompt=prompt)

response1 = chain.invoke({'length': 'very short', 'genre': 'horror', 'text': 'Once there was a coder'})
response2 = chain.invoke({'length': 'very short', 'genre': 'rom-com', 'text': 'And the Queen died'})

print('\n'.join(response1['text'].replace('\n', '.').split('.')))
print('\n'.join(response2['text'].replace('\n', '.').split('.')))
# Out:
#  named Sarah who was always fascinated by the dark side of technology
#
#
# Sarah had always been drawn to the mysterious and sinister side of technology
#  While others saw coding as a means to create beautiful websites and efficient software, she saw it as a gateway to the unknown
#  She spent hours poring over forums and blogs, searching for the latest advancements in coding that would take her deeper into the dark world she craved
#
#
# One day, Sarah stumbled upon a website that promised to grant her access to a hidden realm of the internet
#  Without hesitation, she followed the instructions and entered a code that she had never seen before
#  Suddenly, her screen went black and a chill ran down her spine
#
#
# As she waited for her computer to reboot, Sarah heard a faint whisper coming from the speakers
#  The voice spoke in a language she couldn't understand, but she could feel the malice behind the words
#  Her heart raced as the voice grew louder and more frenzied, until it was screaming in her ears
#
#
# Just when Sarah thought she couldn't take it anymore, the computer finally turned back on
#  She quickly shut it down and tried to shake off the feeling of unease that had settled in her bones
#  But as she lay in bed that night, she couldn't help but feel like something
#
#
# And the Queen died, leaving behind a kingdom in mourning and a heartbroken King
#  He had loved her deeply, but their marriage had been one of duty rather than love
#  They both knew it, but the King couldn't help but feel regret for not expressing his true feelings to her
#
#
# As he sat alone in the palace, memories of their time together flooded his mind
#  He remembered their first meeting, how her laughter had captured his heart
#  And now, she was gone, and he would never have the chance to tell her how he truly felt
#
#
# But then, a knock on the door interrupted his thoughts
#  It was the Queen's best friend, who had always been there to offer her support and advice
#  She had also been secretly in love with the King, but never had the courage to tell him
#
#
# As they talked, the King realized that the Queen's friend was the one who had truly captured his heart
#  He had been blind to her love all this time, but now he saw her in a different light
#  And so, with the Queen's blessing from above, the King and her best friend fell in love and got married
#
#
# The kingdom rejoiced at the news, and the King finally found the love and happiness he had been searching for
#  As they

# %%
#2.5 LangChain using Local LLMs

# !pip install transformers==4.35.2 torch==2.1.0+cu121
# !pip install einops==0.7.0 accelerate==0.26.1

import transformers
import torch
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain import HuggingFacePipeline, PromptTemplate, LLMChain

model = "EleutherAI/gpt-neo-125m"
tokenizer = transformers.AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
)

prompt = PromptTemplate.from_template("Tell me something about {entity}")


llm = HuggingFacePipeline(pipeline=pipeline)
chain = LLMChain(llm=llm,prompt=prompt)

print('\n'.join(chain.run('humans').replace('\n','.').split('.')))
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# c:\Users\Sourav Banerjee\anaconda3\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Sourav Banerjee\.cache\huggingface\hub\models--EleutherAI--gpt-neo-125m. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/526M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# Tell me something about humans that is good for animals
#  They are everywhere, and are all part of our heritage
#
#
# Thanks for stopping in there and checking me out, Mr
#  Smith
#
#
# Monday, November 18, 2008
#
# Here's some tips that I have found inirrelskins and squirrelskins
#  The fur is really beautiful
#  The legs are very large and I've seen them all my life!
#  Melanie, what kind of kitten would I recommend?
#
# Wednesday, August 27, 2008
#
# Hi! My brother and sister are living on the coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast coast of my sister was having an aching for a kitten and she was having an achy for kittens and she's had a baby kittens and the kittens she had had had a baby kittens and she's got a kitten and she's have been living and her kittens and she's having a

# %%
import os
from langchain.llms import HuggingFaceHub
from langchain.chains import OpenAIModerationChain
from langchain.prompts import Prompt

huggingface_llm = HuggingFaceHub(repo_id="google/flan-t5-base", model_kwargs={"temperature": 0})
huggingface_llm('What is Earth?')
# Out:
# c:\Users\Sourav Banerjee\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 0.3.0. Use HuggingFaceEndpoint instead.
#   warn_deprecated(
# c:\Users\Sourav Banerjee\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# 'a planet'

# %%
from langchain.llms import HuggingFaceHub
from langchain.chains import LLMChain

prompt_template = """name an {entity}. Output just the name"""
prompt = PromptTemplate.from_template(prompt_template)
huggingface_llm = HuggingFaceHub(repo_id="google/flan-t5-small", model_kwargs={"temperature": 0})

chain = LLMChain(llm=huggingface_llm,prompt=prompt)
print(chain.run({'entity':'country'}))
# Out:
# sweden
