# %%
import os
from dotenv import load_dotenv
import os
# os.environ["OPENAI_API_KEY"] = apikey # set the API key

# %%
# Load the .env file
load_dotenv()
# Out:
# True

# %%
from langchain_openai.llms import OpenAI
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import PromptTemplate

llm = OpenAI() # Create a new instance of the OpenAI class.
chat_llm = ChatOpenAI()

# %%
#4.1.1 LLM
from langchain.llms import OpenAI

llm = OpenAI()
print(llm.invoke("Tell me about stars. Write it in 150 words.Each line should contains 50 words. Organize each line as new line"))
# Out:
# Stars are celestial bodies that are made up of hot gases, primarily hydrogen and helium.
# They are held together by their own gravity and emit light and heat through the process of nuclear fusion.
# Stars come in a variety of sizes, from small red dwarfs to massive blue giants.
# They can also have different colors, ranging from red to blue, depending on their temperature.
# Stars are constantly changing and evolving, with some eventually dying and exploding into supernovas.
# They serve as the building blocks for galaxies and play a crucial role in the universe's structure.
# The brightness of a star is measured in magnitude, with the lower the number, the brighter the star.
# Some stars are visible to the naked eye, while others can only be seen with the help of telescopes.
# Stars have been a source of fascination and wonder for humans for centuries, inspiring myths, legends and scientific discoveries.
# ...

# %%
#4.1.2 ChatModel
from langchain.schema.messages import HumanMessage, SystemMessage
import os
from langchain.chat_models import ChatOpenAI

messages = [
    SystemMessage(content="You're a helpful assistant. Answer me for following question. Answer should be organized in such way that after 50 words new line would be started."),
    HumanMessage(content="What should we do to stop pollution?"),
]


print(chat_llm.invoke(messages))
# Out:
# content='There are several steps that can be taken to stop pollution. Promoting the use of renewable energy sources, reducing waste by recycling and reusing materials, enforcing stricter environmental regulations on industries, encouraging sustainable practices in agriculture, and raising awareness about the importance of protecting the environment are all crucial measures that can help mitigate pollution. \n\nAdditionally, individuals can make a difference by reducing their own carbon footprint through actions such as using public transportation, biking or walking instead of driving, conserving energy at home, and avoiding single-use plastics. By collectively working together at both the individual and societal levels, we can effectively combat pollution and create a healthier planet for future generations.' response_metadata={'token_usage': {'completion_tokens': 131, 'prompt_tokens': 49, 'total_tokens': 180, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'complet
# ...

# %%
print(chat_llm.invoke(messages).content)
# Out:
# To stop pollution, we must prioritize sustainable practices like reducing waste, using renewable energy sources, promoting public transportation, and implementing stricter regulations for industries. Educating communities about the importance of environmental conservation is crucial. Encouraging individuals to reduce their carbon footprint through small changes also plays a significant role in combating pollution.

# %%
#4.2.1 PromptTemplate

from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chains import LLMChain

prompt = PromptTemplate.from_template(" Suggest {number} names for a {domain} startup?")
chain = LLMChain(llm=llm,prompt=prompt)

print(chain.run({'number':'5','domain':'cooking'}))
print(chain.run({'number':'2','domain':'AI'}))
# Out:
# 1. "The Culinary Collective"
# 2. "Sizzle & Spice"
# 3. "Kitchen Creations Co."
# 4. "Taste Maven"
# 5. "Cooking Craze Co."
#
#
# 1. "MindForge AI"
# 2. "NeuroNexus AI"

# %%
#4.2.2 ChatPromptTemplate
from langchain.prompts import PromptTemplate
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

template="You are a helful assistant who can gives {category} for given input"
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
human_template="{text}"

human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# %%
chat_llm(chat_prompt.format_prompt(category="meaning", text='Rude').to_messages())
# Out:
# AIMessage(content='"Rude" is an adjective used to describe behavior that is disrespectful, impolite, or offensive towards others. It can involve actions, words, or attitudes that are considered discourteous or inconsiderate.', response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 26, 'total_tokens': 71, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1ad7a05a-650e-4c75-adb1-20f9e6041c6c-0')
